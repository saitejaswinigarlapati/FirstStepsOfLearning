# %%
a="Thiaisalphabetic"
print("a ",a.isalpha()) # only letters
b="Thia is alphabetic"
print("b ",b.isalpha())
# Out:
# a  True
# b  False

# %%
a="123abcd"
a.isalnum()
# Out:
# True

# %%
b="123"
b.isdigit() #only digits
# Out:
# True

# %%
import re
p=r'[0-9]'
num="123"
print(bool(re.match(p,num)))
# Out:
# True
