# %%
import hashlib

text=input("enter some text : ")
hash_key=hashlib.sha512(text.encode()).hexdigest()
print(hash_key)
# Out:
# enter some text : hello this hash key is same where evere u go
# 87433d7f046d0a168fd4bea6433d2c33102d881bbb8c8263b0e292828f00595d3c0ee0e03bfbac45026fd16661acadafbf6ee47c3474c798e2c03085ea8bf85e
