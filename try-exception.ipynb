# %%
#Zero Division error
a=1
b=0
try :
    a/b
    print(a/b)
except ZeroDivisionError as e:
    print("Error :" ,e)
    print("Can't divided a number by 0")
# Out:
# Error : division by zero
# Can't divided a number by 0

# %%
#Type error
a=1
b="#"
try :
    r=a/b
    print(r)
except TypeError as e :
    print("Error :" ,e)
# Out:
# Error : unsupported operand type(s) for /: 'int' and 'str'

# %%
#Value error
try :
    b=int(input())
    print(b)
except ValueError as e :
    print("Error :" ,e)
# Out:
# #\
# Error : invalid literal for int() with base 10: '#\\'

# %%
n=int(input("no.of input's"))
for i in range(n):
    try:
        a,b=map(int,input().split())
        r=a/b
        print(int(r))
    except ZeroDivisionError:
        print("Error Code: integer division or modulo by zero")
    except Exception as e:
        print("Error Code:",e)
# Out:
# no.of input's3
# 1 0
# Error Code: integer division or modulo by zero
# 1 @
# Error Code: invalid literal for int() with base 10: '@'
#  #
# Error Code: invalid literal for int() with base 10: '#'

# %%
n=int(input()) 
for i in range(n):
    a=set(input().split())
    print(a)
# Out:
# 1
# 1 2 3
# {'3', '1', '2'}

# %%
n=int(input()) 
for i in range(n):
    n,*m=input().split()
    
print(n)
print(m)
# Out:
# 2
# 1 2 3 4 5
# 1 2 3 6 7 8 0
# 1
# ['2', '3', '6', '7', '8', '0']

# %%
n=int(input()) 
for i in range(n):
    n,*m=input().split()
    query_name=input()
    a=0
    if n==query_name:
        for j in m:
            a+=int(j)
        print(a)
        print(a/len(m))
# Out:
# 1
# w 1 2 3
# w

# %%
n=(1,2)
t=hash(n)
print(t)
# Out:
# -3550055125485641917

# %%
n = int(input())
integer_list = input().split()

integer_list = list(map(int, integer_list))

# Step 4: Create a tuple
integer_tuple = tuple(integer_list)

# %%
n=tuple((map(int,input().split())))
print(n)
# Out:
# 1 2 3
# (1, 2, 3)

# %%
width = 50
print('text alignment center'.center(width,'-') )
print('text alignment right'.rjust(width,'-') )
print('text alignment left'.ljust(width,'-') )
print()
print('text alignment center'.center(width) )
print('text alignment right'.rjust(width) )
print('text alignment left'.ljust(width) )
# Out:
# --------------text alignment center---------------
# ------------------------------text alignment right
# text alignment left-------------------------------
#
#               text alignment center
#                               text alignment right
# text alignment left

# %%
import pandas as pd

# Create a dictionary with your data
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['Los Angeles', 'Chicago' ,'New York']
}

# Create a DataFrame from the dictionary
df = pd.DataFrame(data)

# Print the DataFrame
print(df)
# Out:
#       Name  Age         City
# 0    Alice   25  Los Angeles
# 1      Bob   30      Chicago
# 2  Charlie   35     New York

# %%
#unpacking the list
l=[1,2,3,4]
a,b,c,d=l
print(a)
# Out:
# 1

# %%
#unpacking the tuple
product = (2, "Milk", True)
number, name, is_fresh = product
print(name)
# Out:
# Milk

# %%
#The * operator in tuple unpacking is used to gather multiple elements from the tuple into a list. 
#This is useful when dealing with tuples of unknown length.
scores = (98, 96, 91, 88, 64)
winner, *rest = scores
print(winner)
print(rest)
# Out:
# 98
# [96, 91, 88, 64]

# %%
guests = {"Mery", "Anna", "Jonathan"}
print(guests)
print(guests[0]) #error
#sets do not support indexing

# %%
sets={1,2,3,4}
sets.add(5)
print(sets)
#sets do not support append() function
sets.clear()
#removes every element in the set
print(sets)
# Out:
# {1, 2, 3, 4, 5}
# set()

# %%
s1={1,2,3,'a','c','z'}
s2={'a','b','c','x','y','z'}
a=s1.union(s2)
print("a : ",a)
b=s1.difference(s2)
print("b : ",b)
c=s2.difference(s1)
print("c : " ,c)
# Out:
# a :  {1, 2, 3, 'y', 'z', 'a', 'b', 'c', 'x'}
# b :  {1, 2, 3}
# c :  {'b', 'x', 'y'}

# %%
#Dictionaries are collection types used to store data in key:value pairs, which are considered as items.
d={"Name" :"sai","Salary" :"20K","Company": "XYZ"}
print(d)

b=list(d.keys())
print("keys : ",b)

a=list(d.values())
print("Values : ",a)

c=list(d.items())
print("Items : ",c)

#get()

#updaate
d.update({"JOING YEAR ":"2xxx"})
print()
print("updated dictionary : ")
print(d)

#pop() --> removes the element d.pop("Name")
# in --> used to check whether the keey is present in dictionary or not
#To check if a value occurs in a dictionary, you need to use the values() function.
print("Name" in d)
# Out:
# {'Name': 'sai', 'Salary': '20K', 'Company': 'XYZ'}
# keys :  ['Name', 'Salary', 'Company']
# Values :  ['sai', '20K', 'XYZ']
# Items :  [('Name', 'sai'), ('Salary', '20K'), ('Company', 'XYZ')]
#
# updated dictionary :
# {'Name': 'sai', 'Salary': '20K', 'Company': 'XYZ', 'JOING YEAR ': '2xxx'}
# True

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 a='sad'
# ----> 2 a[1]="w"
#       3 print(a)
#
# TypeError: 'str' object does not support item assignment

# %%
# Define a task for each number
month = int(input("Enter a month (1-12): "))

if month == 1:       
    print("You will spend some time with your mom and let her know what you think about her. Best of luck!")
elif month == 2:
    print("Send me what is your hidden power, I mean what are your good skills?")
elif month == 3:
    print("Make someone happy. Best of luck. If you do that, send me 'done'.")
elif month == 4: 
    print("What are your bad habits?")
elif month == 5:
    print("Where are you from?")
elif month == 6:
    print("What is your name?")
elif month == 7:
    print("What class do you study in?")
elif month == 8:
    print("What is your dream wish?")
elif month == 9:
    print("Why are you learning coding?")
elif month == 10:
    print("Can you make me happy?")
elif month == 11:
    print("What is your favorite hobby?")
elif month == 12:
    print("Just answer all my questions. Best of luck! I know you won't do that because my questions are not good, right? And this is my bad habit. Please make me happy! 🥺🥺")
else:
    print("Invalid month. Please enter a number between 1 and 12.")
# Out:
# Enter a month (1-12): 6
# What is your name?

# %%
import random
print("Hey! What's  up ! Let's play a game. ")
n=random.randrange(0,1)
print(n)
# Out:
# Hey! What's  up ! Let's play a game.
# 0

# %%
import random

# List of options
Moves = ["Rock","Paper","Scissors"]

# Randomly select one option
Computer_Move = random.choice(Moves)

User_Move=str(input("Enter ur move : ").capitalize())
if User_Move not in Moves :
    print("invalid move!")
    while True:
        User_Move=str(input("Enter a valid move :"))
        if User_Move in Moves :
            

else:
    print("Compute_Move =",Computer_Move)
    print("Your Move = ",User_Move)
    if User_Move=="Rock":
        if  Computer_Move=="Paper":
            print("Computer own!")
        elif Computer_Move=="Scissors":
            print("You own !")
        elif Computer_Move=="Rock":
            print("It's a tie!")
    if User_Move=="Paper":
        if  Computer_Move=="Paper":
            print("It's a tie!")
        elif Computer_Move=="Scissors":
            print("Computer own!")
        elif Computer_Move=="Rock":
            print("You own!")
    if User_Move=="Scissors":
        if  Computer_Move=="Paper":
            print("You own!")
        elif Computer_Move=="Scissors":
            print("It's a tie!")
        elif Computer_Move=="Rock":
            print("Computer own!")
# Out:
# Enter ur move : ddj
# invalid move!
# Enter a valid move :hjfd
# Enter a valid move :paper
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 13
#      11     print("invalid move!")
#      12     while True:
# ---> 13         User_Move=str(input("Enter a valid move :"))
#      15 else:
#      16     print("Compute_Move =",Computer_Move)
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1175, in Kernel.raw_input(self, prompt)
#    1171 if not self._allow_stdin:
#    1172     raise StdinNotImplementedError(
#    1173         "raw_input was called, but this frontend does not support input requests."
#    1174     )
# -> 1175 return self._input_request(
#    1176     str(prompt),
#    1177     self._parent_ident["shell"],
#    1178     self.get_parent("shell"),
#    1179     password=False,
#    1180 )
#
# ...

# %%
import random

# List of options
Moves = ["Rock","Paper","Scissors"]

# Randomly select one option
Computer_Move = random.choice(Moves)

User_Move=str(input("Enter ur move : ").capitalize())
print("Compute_Move =",Computer_Move)
def game(Computer_Move,User_Move):
    if User_Move=="Rock":
        if  Computer_Move=="Paper":
            print("Computer own!")
        elif Computer_Move=="Scissors":
            print("You own !")
        elif Computer_Move=="Rock":
            print("It's a tie!")
    if User_Move=="Paper":
        if  Computer_Move=="Paper":
            print("It's a tie!")
        elif Computer_Move=="Scissors":
            print("Computer own!")
        elif Computer_Move=="Rock":
            print("You own!")
    if User_Move=="Scissors":
        if  Computer_Move=="Paper":
            print("You own!")
        elif Computer_Move=="Scissors":
            print("It's a tie!")
        elif Computer_Move=="Rock":
            print("Computer own!")

game(Computer_Move,User_Move)
# Out:
# Enter ur move : rock
# Compute_Move = Scissors
# You own !

# %%
import random

Moves=["Rock","Paper","Scissors"]
Computer_Move=random.choice(Moves)
User_Move=str(input("Enter your Move : ").capitalize())
def game(Computer_Move,User_Move):
    if User_Move=="Rock":
        if  Computer_Move=="Paper":
            print("Computer own!")
        elif Computer_Move=="Scissors":
            print("You own !")
        elif Computer_Move=="Rock":
            print("It's a tie!")
    if User_Move=="Paper":
        if  Computer_Move=="Paper":
            print("It's a tie!")
        elif Computer_Move=="Scissors":
            print("Computer own!")
        elif Computer_Move=="Rock":
            print("You own!")
    if User_Move=="Scissors":
        if  Computer_Move=="Paper":
            print("You own!")
        elif Computer_Move=="Scissors":
            print("It's a tie!")
        elif Computer_Move=="Rock":
            print("Computer own!")
game(Computer_Move,User_Move)
# Out:
# Enter your Move : paper
# It's a tie!

# %%
import random

Moves=["Rock","Paper","Scissors"]
Computer_Move=random.choice(Moves)
User_Move=str(input("Enter your Move : ").capitalize())

def game(Computer_Move,User_Move):
    if User_Move not in Moves:
        print("Not a valid move. Try again!")
        User_Move=str(input().capitalize())
        game(Computer_Move,User_Move)
        print("Computer Move :",Computer_Move)
        print("Your Move : ",User_Move)
    else:
        if User_Move=="Rock":
            if  Computer_Move=="Paper":
                print("Computer own!")
            elif Computer_Move=="Scissors":
                print("You own !")
            elif Computer_Move=="Rock":
                print("It's a tie!")
        if User_Move=="Paper":
            if  Computer_Move=="Paper":
                print("It's a tie!")
            elif Computer_Move=="Scissors":
                print("Computer own!")
            elif Computer_Move=="Rock":
                print("You own!")
        if User_Move=="Scissors":
            if  Computer_Move=="Paper":
                print("You own!")
            elif Computer_Move=="Scissors":
                print("It's a tie!")
            elif Computer_Move=="Rock":
                print("Computer own!")
        
game(Computer_Move,User_Move)
# Out:
# Enter your Move : sad
# Not a valid move. Try again!
# dsf
# Not a valid move. Try again!
#
# Not a valid move. Try again!
# ds
# Not a valid move. Try again!
# paper
# Computer own!
# Computer Move : Scissors
# Your Move :  Paper
# Computer Move : Scissors
# Your Move :  Ds
# Computer Move : Scissors
# Your Move :
# Computer Move : Scissors
# Your Move :  Dsf
